# %% [markdown]
# # 选取自编码器结构

# %% [markdown]
# ## 1. 对比各种结构的自编码器效果

# %% [markdown]
# 本例中，Autoencoder的encoder是2层的MLP。第1层的单元数取3～8，第2层的单元数比第一层单元数少，且不大于5。decoder与encoder对称。尝试几种网络结构，以训练若干次后的测试误差为指标，评价各种结构的优劣。

# %% [markdown]
# 划分训练集和测试集

# %%
from Network import *
import pandas as pd
import torch

# 选取需要的列
COLUMN_INDEX = [
    "Temp (°C)",
    "Dew Point Temp (°C)",
    "Rel Hum (%)",
    "Wind Spd (km/h)",
    "Stn Press (kPa)",
]
data = pd.read_csv("Data/DataSet.csv")[COLUMN_INDEX].to_numpy()
data_tensor = torch.tensor(data, dtype=torch.float32)


# 设置随机种子以确保结果可重复
torch.manual_seed(42)
train_loader, test_loader = Split2Loaders(
    data_tensor, data_tensor, BATCHSIZE=32, RATIO=0.7, SHUFFLE=True
)

# %% [markdown]
# 各训练80个epoch，对比训练结果

# %%
COLUMN_INDEX_COMPARISON = ["LAYER_1", "LAYER_2", "LOSS_TRAIN", "LOSS_TEST"]
df = pd.DataFrame(data=None, columns=COLUMN_INDEX_COMPARISON)

for Layer_1_num in range(3, 9):
    for Layer_2_num in range(2, Layer_1_num):
        if Layer_2_num < 5:
            model = MyAutoencoder(
                input_size=5,
                hidden_size_1=Layer_1_num,
                hidden_size_2=Layer_2_num,
                dropout_prob=0,
            )
            INIT_WEIGHTS_ZERO(model)
            optimizer = torch.optim.Adam(model.parameters(), lr=0.01, weight_decay=1e-5)
            LOSS_HISTORY_TRAIN, LOSS_HISTORY_TEST = TRAIN_NO_PROGRESS_BAR(
                model,
                NUM_EPOCHS=80,
                OPTIMIZER=optimizer,
                TRAIN_LOADER=train_loader,
                TEST_LOADER=test_loader,
                LOSS_TYPE=nn.MSELoss(),
                DEVICE=0,
            )
            RESULT = [
                Layer_1_num,
                Layer_2_num,
                LOSS_HISTORY_TRAIN[-1].cpu().numpy(),
                LOSS_HISTORY_TEST[-1].cpu().numpy(),
            ]
            df = df.append(
                pd.Series(data=RESULT, index=COLUMN_INDEX_COMPARISON), ignore_index=True
            )

# %% [markdown]
# 根据测试误差排序，并保存

# %%
# 按照测试集上的误差，从小到达排列
df = df.sort_values(by="LOSS_TEST", axis=0, ascending=True)
df.to_csv("Networks/AE_Comparison.csv", index=False)
df
# Out:
#    LAYER_1 LAYER_2  LOSS_TRAIN   LOSS_TEST
# 2        4       3   108.45917  105.762184
# 14       8       4   108.44598   105.76972
# 12       8       2   108.53335  105.791824
# 10       7       3   108.44285   105.80078
# 11       7       4  108.510414    105.8092
# 3        5       2  108.405846  105.814545
# 6        6       2   108.45276    105.8208
# 5        5       4   108.48383   105.82611
# 8        6       4   108.46347    105.8425
# 9        7       2  108.504234   105.88325
# 4        5       3  108.523254   105.89539
# 0        3       2   108.48591  105.950554
# 7        6       3   108.51913  105.995705
# 1        4       2   108.57236   106.07988
# 13       8       3  108.494545    106.2559

# %% [markdown]
# ## 2. 训练自编码器

# %% [markdown]
# 根据对比结果，选择网络结构

# %%
# 选取需要的列
COLUMN_INDEX_AE = ["LAYER_1", "LAYER_2"]
layer_1, layer_2 = pd.read_csv("Networks/AE_Comparison.csv").loc[0, COLUMN_INDEX_AE]
layer_1 = int(layer_1)
layer_2 = int(layer_2)

# 以上仅作展示用
layer_1 = 6
layer_2 = 3
print("第1层隐藏层单元数", layer_1, "\n第2层隐藏层单元数", layer_2)
# Out:
# 第1层隐藏层单元数 6
# 第2层隐藏层单元数 3

# %% [markdown]
# 训练网络

# %%
MyAE = MyAutoencoder(
    input_size=5, hidden_size_1=layer_1, hidden_size_2=layer_2, dropout_prob=0.25
)
INIT_WEIGHTS_XAVIER(MyAE)
optimizer = torch.optim.Adam(MyAE.parameters(), lr=0.005, weight_decay=1e-5)
LOSS_HISTORY_TRAIN, LOSS_HISTORY_TEST = TRAIN_WITH_PROGRESS_BAR(
    MyAE,
    NUM_EPOCHS=150,
    OPTIMIZER=optimizer,
    TRAIN_LOADER=train_loader,
    TEST_LOADER=test_loader,
    LOSS_TYPE=nn.MSELoss(),
    DEVICE=0,
    GRAD_MAX=2,
)
# Out:
# PyTorch Version: 2.1.0.dev20230621+cu117
# Training on cuda:0
# ====================================Start training====================================
# Epoch 1/150: 100%|██████████| 384/384 [00:00<00:00, 463.15batch/s, loss=1.73e+3]
# Epoch 2/150: 100%|██████████| 384/384 [00:00<00:00, 462.91batch/s, loss=148]
# Epoch 3/150: 100%|██████████| 384/384 [00:00<00:00, 479.21batch/s, loss=216]
# Epoch 4/150: 100%|██████████| 384/384 [00:00<00:00, 482.48batch/s, loss=251]
# Epoch 5/150: 100%|██████████| 384/384 [00:00<00:00, 466.75batch/s, loss=281]
# Epoch 6/150: 100%|██████████| 384/384 [00:00<00:00, 478.42batch/s, loss=220]
# Epoch 7/150: 100%|██████████| 384/384 [00:00<00:00, 489.44batch/s, loss=227]
# Epoch 8/150: 100%|██████████| 384/384 [00:00<00:00, 494.73batch/s, loss=282]
# Epoch 9/150: 100%|██████████| 384/384 [00:00<00:00, 492.76batch/s, loss=147]
# Epoch 10/150: 100%|██████████| 384/384 [00:00<00:00, 498.28batch/s, loss=237]
# Epoch 11/150: 100%|██████████| 384/384 [00:00<00:00, 477.69batch/s, loss=174]
# Epoch 12/150: 100%|██████████| 384/384 [00:00<00:00, 480.78batch/s, loss=228]
# Epoch 13/150: 100%|██████████| 384/384 [00:00<00:00, 477.32batch/s, loss=139]
# Epoch 14/150: 100%|██████████| 384/384 [00:00<00:00, 488.57batch/s, loss=338]
# Epoch 15/150: 100%|██████████| 384/384 [00:00<00:00, 489.94batch/s, loss=202]
# Epoch 16/150: 100%|██████████| 384/384 [00:00<00:00, 480.43batch/s, loss=181]
# Epoch 17/150: 100%|██████████| 384/384 [00:00<00:00, 484.39batch/s, loss=263]
# Epoch 108/150: 100%|██████████| 384/384 [00:00<00:00, 414.91batch/s, loss=37.6]
# Epoch 109/150: 100%|██████████| 384/384 [00:00<00:00, 437.93batch/s, loss=33.5]
# Epoch 110/150: 100%|██████████| 384/384 [00:00<00:00, 436.90batch/s, loss=71.8]
# Epoch 111/150: 100%|██████████| 384/384 [00:00<00:00, 440.53batch/s, loss=64.8]
# Epoch 112/150: 100%|██████████| 384/384 [00:00<00:00, 423.62batch/s, loss=34.8]
# Epoch 113/150: 100%|██████████| 384/384 [00:00<00:00, 401.34batch/s, loss=70.2]
# Epoch 114/150: 100%|██████████| 384/384 [00:00<00:00, 436.07batch/s, loss=49.2]
# Epoch 115/150: 100%|██████████| 384/384 [00:00<00:00, 429.38batch/s, loss=54.1]
# Epoch 116/150: 100%|██████████| 384/384 [00:00<00:00, 430.28batch/s, loss=53.4]
# Epoch 117/150: 100%|██████████| 384/384 [00:00<00:00, 450.92batch/s, loss=41.4]
# Epoch 118/150: 100%|██████████| 384/384 [00:00<00:00, 434.57batch/s, loss=56.5]
# Epoch 119/150: 100%|██████████| 384/384 [00:00<00:00, 442.06batch/s, loss=62.9]
# Epoch 120/150: 100%|██████████| 384/384 [00:00<00:00, 423.45batch/s, loss=46.1]
# Epoch 121/150: 100%|██████████| 384/384 [00:00<00:00, 435.26batch/s, loss=37.1]
# Epoch 122/150: 100%|██████████| 384/384 [00:00<00:00, 425.51batch/s, loss=72.5]
# Epoch 123/150: 100%|██████████| 384/384 [00:00<00:00, 449.03batch/s, loss=45.1]
# Epoch 124/150: 100%|██████████| 384/384 [00:00<00:00, 438.27batch/s, loss=62]
# Epoch 125/150: 100%|██████████| 384/384 [00:00<00:00, 434.00batch/s, loss=26.4]
# Epoch 126/150: 100%|██████████| 384/384 [00:00<00:00, 435.36batch/s, loss=31.4]
# Epoch 127/150: 100%|██████████| 384/384 [00:00<00:00, 445.48batch/s, loss=55.4]
# Epoch 128/150: 100%|██████████| 384/384 [00:00<00:00, 430.89batch/s, loss=49.7]
# Epoch 129/150: 100%|██████████| 384/384 [00:00<00:00, 448.98batch/s, loss=73.3]
# Epoch 130/150: 100%|██████████| 384/384 [00:00<00:00, 428.17batch/s, loss=70.3]
# Epoch 131/150: 100%|██████████| 384/384 [00:00<00:00, 446.48batch/s, loss=35.4]
# Epoch 132/150: 100%|██████████| 384/384 [00:00<00:00, 425.40batch/s, loss=43.6]
# Epoch 133/150: 100%|██████████| 384/384 [00:00<00:00, 444.25batch/s, loss=92.1]
# Epoch 134/150: 100%|██████████| 384/384 [00:00<00:00, 442.86batch/s, loss=125]
# Epoch 135/150: 100%|██████████| 384/384 [00:00<00:00, 434.38batch/s, loss=38.1]
# Epoch 136/150: 100%|██████████| 384/384 [00:00<00:00, 442.08batch/s, loss=32.4]
# Epoch 137/150: 100%|██████████| 384/384 [00:00<00:00, 426.53batch/s, loss=53.6]
# Epoch 138/150: 100%|██████████| 384/384 [00:00<00:00, 428.20batch/s, loss=42.5]
# Epoch 139/150: 100%|██████████| 384/384 [00:00<00:00, 429.61batch/s, loss=56.6]
# Epoch 140/150: 100%|██████████| 384/384 [00:00<00:00, 441.76batch/s, loss=61.1]
# Epoch 141/150: 100%|██████████| 384/384 [00:00<00:00, 443.61batch/s, loss=63.1]
# Epoch 142/150: 100%|██████████| 384/384 [00:00<00:00, 431.63batch/s, loss=68.8]
# Epoch 143/150: 100%|██████████| 384/384 [00:00<00:00, 443.25batch/s, loss=84.6]
# Epoch 144/150: 100%|██████████| 384/384 [00:00<00:00, 435.49batch/s, loss=68.7]
# Epoch 145/150: 100%|██████████| 384/384 [00:00<00:00, 442.68batch/s, loss=33.8]
# Epoch 146/150: 100%|██████████| 384/384 [00:00<00:00, 433.10batch/s, loss=99.1]
# Epoch 147/150: 100%|██████████| 384/384 [00:00<00:00, 446.83batch/s, loss=29.2]
# Epoch 148/150: 100%|██████████| 384/384 [00:00<00:00, 440.33batch/s, loss=25.4]
# Epoch 149/150: 100%|██████████| 384/384 [00:00<00:00, 429.27batch/s, loss=66.5]
# Epoch 150/150: 100%|██████████| 384/384 [00:00<00:00, 447.68batch/s, loss=106]
# ====================================Finish training====================================

# %% [markdown]
# 可视化

# %%
from Visualization import *

LossEpochPlot(
    LOSS_HISTORY=(LOSS_HISTORY_TRAIN, LOSS_HISTORY_TEST),
    LEGEND=["训练集", "测试集"],
    TITLE="Loss-Epoch图线",
    SAVE_FIG=True,
)
# Out:
# /home/ctc/桌面/Git Projects/Optimization_Group_Work/Visualization.py:147: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
# /home/ctc/桌面/Git Projects/Optimization_Group_Work/Visualization.py:149: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "facecolor" which is no longer supported as of 3.3 and will become an error two minor releases later
# /home/ctc/桌面/Git Projects/Optimization_Group_Work/Visualization.py:149: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "edgecolor" which is no longer supported as of 3.3 and will become an error two minor releases later
# /home/ctc/桌面/Git Projects/Optimization_Group_Work/Visualization.py:149: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "orientation" which is no longer supported as of 3.3 and will become an error two minor releases later
# /home/ctc/桌面/Git Projects/Optimization_Group_Work/Visualization.py:149: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "bbox_inches_restore" which is no longer supported as of 3.3 and will become an error two minor releases later
# /home/ctc/anaconda3/envs/D2L/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "orientation" which is no longer supported as of 3.3 and will become an error two minor releases later
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/ctc/anaconda3/envs/D2L/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "facecolor" which is no longer supported as of 3.3 and will become an error two minor releases later
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/ctc/anaconda3/envs/D2L/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "edgecolor" which is no longer supported as of 3.3 and will become an error two minor releases later
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/ctc/anaconda3/envs/D2L/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "bbox_inches_restore" which is no longer supported as of 3.3 and will become an error two minor releases later
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# ## 3. 保存网络

# %%
torch.save(MyAE.encoder.state_dict(), "Networks/Encoder.pth")
torch.save(MyAE.decoder.state_dict(), "Networks/Decoder.pth")

# %% [markdown]
# 调用保存的网络示例

# %%
net_temp = MyAutoencoder(5, layer_1, layer_2, dropout_prob=0).encoder
net_temp.load_state_dict(torch.load("Networks/Encoder.pth"))

net_temp.eval()
with torch.no_grad():
    print(net_temp(torch.randn(1, 5)))
# Out:
# tensor([[-2.7975,  4.3741,  0.8586]])
